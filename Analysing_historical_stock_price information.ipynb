# %%
import pandas as pd
import pandas.io.data as web
# Out:
# /Users/cP/Desktop/Computing/User/lib/python2.7/site-packages/pandas/io/data.py:35: FutureWarning:
# The pandas.io.data module is moved to a separate package (pandas-datareader) and will be removed from pandas in a future version.
# After installing the pandas-datareader package (https://github.com/pydata/pandas-datareader), you can change the import ``from pandas.io import data, wb`` to ``from pandas_datareader import data, wb``.
#   FutureWarning)

# %%
dax = web.DataReader ('^GDAXI', data_source='yahoo', start = '3/28/2010', end = '3/28/2016')
dax.tail()
# Out:
#                     Open          High          Low         Close     Volume  \
# Date
# 2016-03-18   9905.669922   9961.480469  9822.519531   9950.799805  202856000
# 2016-03-21   9893.259766  10095.459961  9863.830078   9948.639648   76585600
# 2016-03-22   9836.280273   9990.000000  9762.570312   9990.000000   79178900
# 2016-03-23  10046.940430  10112.169922  9964.629883  10022.929688   80750700
# 2016-03-24   9974.599609   9977.990234  9845.370117   9851.349609   71212100
#
#                Adj Close
# Date
# 2016-03-18   9950.799805
# 2016-03-21   9948.639648
# 2016-03-22   9990.000000
# 2016-03-23  10022.929688
# 2016-03-24   9851.349609

# %%
dax['Log_Ret'] = np.log(dax['Close']/dax['Close'].shift(1))
dax['Volatility'] = pd.rolling_std(dax['Log_Ret'], window = 252) * np.sqrt(252)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4505259518bc> in <module>()
# ----> 1 dax['Log_Ret'] = np.log(dax['Close']/dax['Close'].shift(1))
#       2 dax['Volatility'] = pd.rolling_std(dax['Log_Ret'], window = 252) * np.sqrt(252)
#
# NameError: name 'np' is not defined

# %%
# %matplotlib inline
dax[['Close', 'Volume','Open']].plot(subplots=True, color='b', figsize=(20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x10dae1550>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x10f5a86d0>], dtype=object)

# %% [markdown]
# x = np.linspace(0,1,100)
# y = x**2
# z = np.polyfit(x,y,1)
# p = np.poly1d(z)
# fs.plot(x,y,'ro',x,p(x),'r--')
# fs.ylabel("a")
# fs.xlabel("LogSlowFast")
# fs.show()
